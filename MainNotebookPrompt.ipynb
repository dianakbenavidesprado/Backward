# %%
import os
os.system('cmd command')
# Out:
# 32512

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/HiDePrompt
# Out:
# /content/drive/MyDrive/HiDePrompt

# %%
# !pip install -q condacolab

# %%
import condacolab
condacolab.install()
# Out:
# ⏬ Downloading https://github.com/jaimergp/miniforge/releases/download/24.11.2-1_colab/Miniforge3-colab-24.11.2-1_colab-Linux-x86_64.sh...
# 📦 Installing...
# 📌 Adjusting configuration...
# 🩹 Patching environment...
# ⏲ Done in 0:00:11
# 🔁 Restarting kernel...

# %%
# %cd /content/drive/MyDrive/HiDePrompt/HiDePrompt
# Out:
# /content/drive/MyDrive/HiDePrompt/HiDePrompt

# %%
# !pip install -r requirements.txt
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 68.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 141.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 179.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 888.1/888.1 MB 15.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 594.3/594.3 MB 50.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 116.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.0/88.0 MB 67.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 954.8/954.8 kB 58.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 706.8/706.8 MB 27.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.1/193.1 MB 53.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 34.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.6/63.6 MB 41.3 MB/s eta 0:00:00
# ...

# %%
# %cd /content/drive/MyDrive/HiDePrompt/HiDePrompt/
# Out:
# /content/drive/MyDrive/HiDePrompt/HiDePrompt

# %%
#HiDePrompt TII - small dino imagenetr - hyperparameters from paper
# !torchrun --nproc_per_node=1 main.py imr_hideprompt_5e --original_model vit_small_patch16_224.dino --model vit_small_patch16_224.dino --batch-size 128 --data-path ./datasets/ --output_dir ./output/hide_imr_dino --epochs 50 --crct_epochs 10 --sched constant --seed 20 --train_inference_task_only --lr 0.0005 --pct 0.1
# Out:
# Namespace(subparser_name='imr_hideprompt_5e', pct=1.0, batch_size=64, epochs=10, original_model='vit_small_patch16_224.dino', model='vit_small_patch16_224.dino', input_size=224, pretrained=True, drop=0.0, drop_path=0.0, opt='adam', opt_eps=1e-08, opt_betas=(0.9, 0.999), clip_grad=1.0, momentum=0.9, weight_decay=0.0, reinit_optimizer=True, sched='constant', lr=0.0005, lr_noise=None, lr_noise_pct=0.67, lr_noise_std=1.0, warmup_lr=1e-06, min_lr=1e-05, decay_epochs=30, warmup_epochs=0, cooldown_epochs=10, patience_epochs=10, decay_rate=0.1, unscale_lr=True, color_jitter=None, aa=None, smoothing=0.1, train_interpolation='bicubic', reprob=0.0, remode='pixel', recount=1, data_path='./datasets/', dataset='Split-Imagenet-R', shuffle=False, output_dir='./output/hide_imr_dino', device='cuda', seed=20, eval=False, num_workers=4, pin_mem=True, world_size=1, dist_url='env://', num_tasks=10, train_mask=True, task_inc=False, use_g_prompt=False, g_prompt_length=5, g_prompt_layer_idx=[], use_prefix_tu
# ...

# %%
#HiDePrompt TII - small dino cifar100 - hyperparameters from paper
# !torchrun --nproc_per_node=1 main.py cifar100_hideprompt_5e --original_model vit_small_patch16_224.dino --model vit_small_patch16_224.dino --batch-size 24 --data-path ./datasets/ --output_dir ./output/hide_cifar100_dino/ --epochs 20 --crct_epochs 10 --sched constant --seed 20 --train_inference_task_only --lr 0.0005 --pct 0.1
# Out:
# Namespace(subparser_name='cifar100_hideprompt_5e', batch_size=24, epochs=20, original_model='vit_small_patch16_224.dino', model='vit_small_patch16_224.dino', input_size=224, pretrained=True, drop=0.0, drop_path=0.0, opt='adam', opt_eps=1e-08, opt_betas=(0.9, 0.999), clip_grad=1.0, momentum=0.9, weight_decay=0.0, reinit_optimizer=True, sched='constant', lr=0.0005, lr_noise=None, lr_noise_pct=0.67, lr_noise_std=1.0, warmup_lr=1e-06, min_lr=1e-05, decay_epochs=30, warmup_epochs=0, cooldown_epochs=10, patience_epochs=10, decay_rate=0.1, unscale_lr=True, color_jitter=None, aa=None, smoothing=0.1, train_interpolation='bicubic', reprob=0.0, remode='pixel', recount=1, data_path='./datasets/', dataset='Split-CIFAR100', shuffle=False, output_dir='./output/hide_cifar100_dino/', device='cuda', seed=20, eval=False, num_workers=4, pin_mem=True, world_size=1, dist_url='env://', num_tasks=10, train_mask=True, task_inc=False, use_g_prompt=False, g_prompt_length=5, g_prompt_layer_idx=[], use_prefix_tu
# ...

# %%
#HiDePrompt TII - small dino five datasets - hyperparameters from paper
# !torchrun --nproc_per_node=1 main.py five_datasets_hideprompt_5e --original_model vit_small_patch16_224.dino --model vit_small_patch16_224.dino --batch-size 128 --data-path ./datasets/ --output_dir ./output/hide_fivedatasets_dino/ --epochs 20 --crct_epochs 10 --sched constant --seed 20 --train_inference_task_only --lr 0.0005 --pct 0.10
# Out:
# Namespace(subparser_name='five_datasets_hideprompt_5e', pct=0.2, batch_size=24, epochs=10, model='vit_small_patch16_224.dino', original_model='vit_small_patch16_224.dino', input_size=224, pretrained=True, drop=0.0, drop_path=0.0, opt='adam', opt_eps=1e-08, opt_betas=(0.9, 0.999), clip_grad=1.0, momentum=0.9, weight_decay=0.0, reinit_optimizer=True, sched='constant', lr=0.0005, lr_noise=None, lr_noise_pct=0.67, lr_noise_std=1.0, warmup_lr=1e-06, min_lr=1e-05, decay_epochs=30, warmup_epochs=5, cooldown_epochs=10, patience_epochs=10, decay_rate=0.1, unscale_lr=True, color_jitter=None, aa=None, smoothing=0.1, train_interpolation='bicubic', reprob=0.0, remode='pixel', recount=1, data_path='./datasets/', dataset='5-datasets', shuffle=False, output_dir='./output/hide_fivedatasets_dino/', device='cuda', seed=20, eval=False, num_workers=4, pin_mem=True, world_size=1, dist_url='env://', num_tasks=5, train_mask=True, task_inc=False, use_g_prompt=False, g_prompt_length=5, g_prompt_layer_idx=[], 
# ...

# %%
#HiDePrompt TII - small dino cub200 - hyperparameters from paper
# !torchrun --nproc_per_node=1 main.py cub_hideprompt_5e --original_model vit_small_patch16_224.dino --model vit_small_patch16_224.dino --batch-size 128 --data-path ./datasets/ --output_dir ./output/hide_cub200_dino/ --epochs 50 --crct_epochs 10 --sched constant --seed 20 --train_inference_task_only --lr 0.0005 --pct 0.1
# Out:
# Namespace(subparser_name='cub_hideprompt_5e', pct=0.3, batch_size=128, epochs=10, original_model='vit_small_patch16_224.dino', model='vit_small_patch16_224.dino', input_size=224, pretrained=True, drop=0.0, drop_path=0.0, opt='adam', opt_eps=1e-08, opt_betas=(0.9, 0.999), clip_grad=1.0, momentum=0.9, weight_decay=0.0, reinit_optimizer=True, sched='constant', lr=0.0005, lr_noise=None, lr_noise_pct=0.67, lr_noise_std=1.0, warmup_lr=1e-06, min_lr=1e-05, decay_epochs=30, warmup_epochs=0, cooldown_epochs=10, patience_epochs=10, decay_rate=0.1, unscale_lr=True, color_jitter=None, aa=None, smoothing=0.1, train_interpolation='bicubic', reprob=0.0, remode='pixel', recount=1, data_path='./datasets/', dataset='Split-CUB200', shuffle=False, output_dir='./output/hide_cub200_dino/', device='cuda', seed=20, eval=False, num_workers=4, pin_mem=True, world_size=1, dist_url='env://', num_tasks=10, train_mask=True, task_inc=False, use_g_prompt=False, g_prompt_length=5, g_prompt_layer_idx=[], use_prefix_t
# ...

# %%
#HiDePrompt WTP and TAP - cifar100 with replay - it is trprompt but without backward
# !torchrun --nproc_per_node=1 main.py cifar100_trprompt --original_model vit_small_patch16_224.dino --model vit_small_patch16_224.dino --batch-size 128 --epochs 1 --crct_epochs 1 --seed 20 --ca_lr 0.005 --prompt_momentum 0.1 --reg 0.1 --length 5 --larger_prompt_lr --data-path ./datasets/ --trained_original_model ./output/hide_cifar100_dino/ --output_dir ./output/hideprompt_cifar100_dino --pct 0.10 --replay_percentage 0.25 --with_backward 0 --with_grpo 0 --with_forward 0 --rep 1
# Out:
# Namespace(subparser_name='cifar100_trprompt', batch_size=128, epochs=1, original_model='vit_small_patch16_224.dino', model='vit_small_patch16_224.dino', input_size=224, pretrained=True, drop=0.0, drop_path=0.0, opt='adam', opt_eps=1e-08, opt_betas=(0.9, 0.999), clip_grad=1.0, momentum=0.9, weight_decay=0.0, reinit_optimizer=True, sched='step', lr=0.03, lr_noise=None, lr_noise_pct=0.67, lr_noise_std=1.0, warmup_lr=1e-06, min_lr=1e-05, decay_epochs=30, warmup_epochs=0, cooldown_epochs=10, patience_epochs=10, decay_rate=0.1, unscale_lr=True, color_jitter=None, aa=None, smoothing=0.1, train_interpolation='bicubic', reprob=0.0, remode='pixel', recount=1, data_path='./datasets/', dataset='Split-CIFAR100', shuffle=False, output_dir='./output/hideprompt_cifar100_dino', device='cuda', seed=20, eval=False, num_workers=4, pin_mem=True, world_size=1, dist_url='env://', num_tasks=10, train_mask=True, task_inc=False, use_g_prompt=False, g_prompt_length=5, g_prompt_layer_idx=[], use_prefix_tune_for
# ...

# %%
#TRPrompt
# %cd /content/drive/MyDrive/HiDePrompt/HiDePrompt/
# Out:
# /content/drive/MyDrive/HiDePrompt/HiDePrompt

# %%
#TRPrompt WTP and TAP - backward and grpo, base trained with hide, cifar 100
# !torchrun --nproc_per_node=1 main.py cifar100_trprompt --original_model vit_small_patch16_224.dino --model vit_small_patch16_224.dino --batch-size 128 --epochs 1 --crct_epochs 1 --seed 20 --ca_lr 0.005 --prompt_momentum 0.1 --reg 0.1 --length 5 --larger_prompt_lr --data-path ./datasets/ --trained_original_model ./output/hide_cifar100_dino/ --output_dir ./output/trprompt_cifar100_dino --pct 0.10 --replay_percentage 0.25 --with_backward 1 --with_grpo 0 --with_forward 0 --rep 1 --task_similarity 0.5 --kappa_low 0.4 --kappa_high 0.7 --lambda_update 0.1 --init_prompt 0
# Out:
# Namespace(subparser_name='cifar100_trprompt', batch_size=128, epochs=1, original_model='vit_small_patch16_224.dino', model='vit_small_patch16_224.dino', input_size=224, pretrained=True, drop=0.0, drop_path=0.0, opt='adam', opt_eps=1e-08, opt_betas=(0.9, 0.999), clip_grad=1.0, momentum=0.9, weight_decay=0.0, reinit_optimizer=True, sched='step', lr=0.03, lr_noise=None, lr_noise_pct=0.67, lr_noise_std=1.0, warmup_lr=1e-06, min_lr=1e-05, decay_epochs=30, warmup_epochs=0, cooldown_epochs=10, patience_epochs=10, decay_rate=0.1, unscale_lr=True, color_jitter=None, aa=None, smoothing=0.1, train_interpolation='bicubic', reprob=0.0, remode='pixel', recount=1, data_path='./datasets/', dataset='Split-CIFAR100', shuffle=False, output_dir='./output/trprompt_cifar100_dino', device='cuda', seed=20, eval=False, num_workers=4, pin_mem=True, world_size=1, dist_url='env://', num_tasks=10, train_mask=True, task_inc=False, use_g_prompt=False, g_prompt_length=5, g_prompt_layer_idx=[], use_prefix_tune_for_g
# ...

# %%
#TRPrompt WTP and TAP - backward and grpo, base trained with hide, imr
# !torchrun --nproc_per_node=1 main.py imr_trprompt --original_model vit_small_patch16_224.dino --model vit_small_patch16_224.dino --batch-size 128 --epochs 1 --crct_epochs 1 --seed 20 --ca_lr 0.005 --prompt_momentum 0.1 --reg 0.1 --length 5 --larger_prompt_lr --data-path ./datasets/ --trained_original_model ./output/hide_imr_dino --output_dir ./output/trprompt_imr_dino --pct 0.20 --replay_percentage 0.5 --with_backward 1 --with_grpo 1 --with_forward 1 --rep 1 --task_similarity 0.5 --kappa_low 0.4 --kappa_high 0.7
# Out:
# Streaming output truncated to the last 5000 lines.
# Backward transfer occurred
# Backward transfer occurred
# Backward transfer occurred
# Backward transfer occurred
# Backward transfer occurred
# Backward transfer occurred
# Backward transfer occurred
# Backward transfer occurred
# STARTING GRPO EVALUATION AT LAYER:  0
# REWARDS POSITIVE
# tensor([2.9964], device='cuda:0')
# REWARDS POSITIVE
# tensor([3.0426, 3.0426, 3.0426, 3.0426, 3.0426, 3.0426, 3.0426, 3.0426, 3.0426,
#         3.0426, 3.0426, 3.0426, 3.0426, 3.0426, 3.0426, 3.0426, 3.0426, 3.0426,
#         3.0426, 3.0426, 3.0426], device='cuda:0')
# REWARDS POSITIVE
# tensor([3.1878], device='cuda:0')
# REWARDS POSITIVE
# tensor([2.9370, 2.9370, 2.9370], device='cuda:0')
# REWARDS POSITIVE
# tensor([3.0336], device='cuda:0')
# REWARDS POSITIVE
# tensor([2.9708], device='cuda:0')
# REWARDS POSITIVE
# tensor([3.0174], device='cuda:0')
# REWARDS POSITIVE
# tensor([2.7395], device='cuda:0')
# REWARDS POSITIVE
# ...
